-- %% [markdown]
-- # [dbo].[product]

-- %%
USE [products]
GO

-- %%
/****** Object:  Table [dbo].[product]    Script Date: 06/12/2024 11:59:08 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[product](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[comercialname] [nvarchar](255) NOT NULL,
	[genericname] [nvarchar](255) NOT NULL,
	[quantity] [int] NOT NULL,
	[lote] [nvarchar](100) NOT NULL,
	[price] [int] NULL,
	[description] [nvarchar](max) NOT NULL,
	[pharmaceuticform] [nvarchar](100) NOT NULL,
	[cum] [nvarchar](50) NOT NULL,
	[finaldate] [date] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %%
SET IDENTITY_INSERT [dbo].[product] ON 
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1007, N'Paracetamol', N'Acetaminofén', 500, N'123456789', 2500, N'Analgésico y antipirético utilizado para aliviar el dolor leve o moderado y reducir la fiebre.', N'Tableta', N'123456789101112', CAST(N'2024-12-25' AS Date))
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1009, N'Ibuprofeno', N'Ibuprofeno', 200, N'987654321', 3500, N'Antiinflamatorio no esteroideo usado para reducir el dolor y la inflamación.', N'Cápsula', N'987654321123456', CAST(N'2024-08-15' AS Date))
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1010, N'Amoxicilina', N'Amoxicilina', 500, N'456789123', 4800, N'Antibiótico utilizado para tratar infecciones bacterianas.', N'Suspensión oral', N'456789123654789', CAST(N'2026-03-10' AS Date))
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1011, N'Loratadina', N'Loratadina', 10, N'654321987', 2200, N'Antihistamínico utilizado para aliviar los síntomas de alergias.', N'Jarabe', N'321987654987654', CAST(N'2025-07-20' AS Date))
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1012, N'Metformina', N'Metformina', 850, N'321456987', 4000, N'Medicamento utilizado para el tratamiento de la diabetes tipo 2.', N'Tableta', N'321456987123654', CAST(N'2025-11-05' AS Date))
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1013, N'Salbutamol', N'Salbutamol', 100, N'111222333', 15000, N'Broncodilatador utilizado para tratar el asma y otros trastornos respiratorios.', N'Aerosol', N'111222333444555', CAST(N'2026-09-12' AS Date))
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1015, N'Acetaminofen', N'Acenta', 2121, N'dsada', 3131, N'dsad', N'dadsad', N'dsads', CAST(N'2024-12-30' AS Date))
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1016, N'Levofloxacino', N'Levofloxacino', 500, N'101112233', 2600, N'Antibiótico utilizado para tratar infecciones bacterianas graves.', N'Tableta', N'101112233567890', CAST(N'2025-03-01' AS Date))
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1031, N'Paracetamolina', N'Paracetamol', 500, N'123456789', 1200, N'Analgésico utilizado para aliviar dolores leves a moderados.', N'Tableta', N'123456789012345', CAST(N'2024-12-31' AS Date))
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1032, N'Amoxicilina', N'Amoxicilina', 250, N'223344556', 2100, N'Antibiótico utilizado para tratar infecciones bacterianas.', N'Cápsula', N'223344556789012', CAST(N'2024-12-23' AS Date))
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1033, N'Omeprazol', N'Omeprazol', 20, N'334455667', 950, N'Medicamento utilizado para tratar problemas gástricos y úlceras', N'Tableta', N'334455667890123', CAST(N'2025-03-21' AS Date))
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1035, N'Clonazepam', N'Clonazepam', 1, N'556677889', 1800, N'Ansiolítico utilizado para tratar la ansiedad y trastornos convulsivos.', N'Tableta', N'556677889012345', CAST(N'2024-12-24' AS Date))
INSERT [dbo].[product] ([id], [comercialname], [genericname], [quantity], [lote], [price], [description], [pharmaceuticform], [cum], [finaldate]) VALUES (1036, N'Metformina', N'Metformina', 500, N'778899001', 2200, N'Medicamento utilizado para controlar los niveles de azúcar en sangre.', N'Tableta', N'778899001234567', CAST(N'2024-12-25' AS Date))
SET IDENTITY_INSERT [dbo].[product] OFF
GO
